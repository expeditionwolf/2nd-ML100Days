# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# Suicide Rates Overview 1985 to 2016在探討自殺與社經發展的關係，自殺不只增加醫療等外部成本，對於內部社會成本之潛在生命損失影響甚劇。因此試圖找出影響的因子，提早介入，減少事件發生。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#     World Bank Dataset Terms of Use。
#     This compiled dataset pulled from four other datasets linked by time and place, and was built to find signals correlated to increased suicide rates among different cohorts globally, across the socio-economic spectrum.
#
# 3. 蒐集而來的資料型態為何
# 資料屬於構化資料，包含country, year, sex, age group, count of suicides, population, suicide rate, country-year composite key, HDI for year, gdp_for_year, gdp_per_capita, generation (based on age grouping average)這幾個欄位，欄位格式包含文字、整數以及小數。
#
# 4. 這組資料想解決的問題如何評估
# 這屬於次集資料，沒有詳細到個人層集的資訊，因此只能做初步的描述性分析，看整體的趨勢，(1)跨國比較，同時間底下，社經程度是否與自殺率相關 (2)相同國加不同時間點的比較，隨著社經發展，自殺率是否有趨勢的增加或下降。
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 扣掉油資成本，單位時間的收入增加。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 整合定位系統以及乘客叫車服務APP，將乘車時間、地點、車資、乘客人數等用戶資訊做收集，再連結圖資以及天氣資料做路線以及派車規劃。
#
# 3. 蒐集而來的資料型態為何
# 資料型態包含做標、日期、數值、文字等型態
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 比較傳統載客方式，與搭配預測模型下的載客的量，以及收入是否提升。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y1,y2):
    """
    請完成這個 Function 後往下執行
    """
    MSE=sum((y-yp)**2)/len(y)
    return MSE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101) #建立一個最小值0，最大值100，共分101塊相等間距的矩陣

y = (x_lin + np.random.randn(101) * 5) * w + b #迴傳101組的隨機數值

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
